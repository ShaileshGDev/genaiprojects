# %% [markdown]
# # Market Basket Analysis using Apriori
# This notebook demonstrates how to perform Market Basket Analysis using the Apriori algorithm on synthetic transaction data from AdventureWorks-like sales.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# Load the dataset
df = pd.read_csv("market_basket.csv")
df.head()
# Out:
#   OrderID Product
# 0  SO1001   Shoes
# 1  SO1001  Bottle
# 2  SO1001    Bike
# 3  SO1002  Helmet
# 4  SO1002  Bottle

# %%
# Convert to list of transactions
transactions = df.groupby('OrderID')['Product'].apply(list).tolist()
transactions[:5]
# Out:
# [['Shoes', 'Bottle', 'Bike'],
#  ['Helmet', 'Bottle', 'Bike'],
#  ['Gloves'],
#  ['Shoes', 'Jersey', 'Socks', 'Helmet'],
#  ['Helmet', 'Shoes', 'Jersey']]

# %%
# Encode transactions to binary matrix
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply Apriori algorithm
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)
frequent_itemsets.sort_values(by='support', ascending=False).head()
# Out:
#    support  itemsets
# 3    0.341  (Helmet)
# 1    0.336  (Bottle)
# 7    0.335   (Socks)
# 2    0.319  (Gloves)
# 6    0.304  (Shorts)

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
rules.sort_values(by='confidence', ascending=False).head()
# Out:
#          antecedents consequents  antecedent support  consequent support  \
# 32  (Bottle, Shorts)     (Socks)               0.098               0.335
# 18    (Bike, Gloves)     (Socks)               0.075               0.335
# 20    (Bike, Helmet)     (Socks)               0.090               0.335
# 31   (Socks, Shorts)    (Bottle)               0.104               0.336
# 25  (Gloves, Shorts)    (Bottle)               0.093               0.336
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 32    0.038    0.387755  1.157478               1.0  0.005170    1.086167
# 18    0.029    0.386667  1.154229               1.0  0.003875    1.084239
# 20    0.033    0.366667  1.094527               1.0  0.002850    1.050000
# 31    0.038    0.365385  1.087454               1.0  0.003056    1.046303
# 25    0.033    0.354839  1.056068               1.0  0.001752    1.029200
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 32       0.150834  0.096203   0.079331    0.250594
# 18       0.144455  0.076115   0.077694    0.236617
# 20       0.094905  0.084184   0.047619    0.232587
# 31       0.089756  0.094527   0.044254    0.239240
# 25       0.058535  0.083333   0.028372    0.226526

# %%
# Filter rules for stronger associations
# strong_rules = rules[(rules['confidence'] >= 0.4) & (rules['lift'] >= 1.2)]
strong_rules = rules[(rules['confidence'] >= 0.1) & (rules['lift'] >= 0.2)]
strong_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#          antecedents       consequents  support  confidence      lift
# 0             (Bike)           (Socks)    0.097    0.342756  1.023153
# 1            (Socks)            (Bike)    0.097    0.289552  1.023153
# 2            (Socks)          (Bottle)    0.113    0.337313  1.003909
# 3           (Bottle)           (Socks)    0.113    0.336310  1.003909
# 4           (Helmet)          (Shorts)    0.107    0.313783  1.032181
# 5           (Shorts)          (Helmet)    0.107    0.351974  1.032181
# 6            (Socks)          (Shorts)    0.104    0.310448  1.021210
# 7           (Shorts)           (Socks)    0.104    0.342105  1.021210
# 8   (Helmet, Bottle)            (Bike)    0.027    0.290323  1.025875
# 10    (Bike, Jersey)          (Bottle)    0.025    0.347222  1.033399
# 12     (Bike, Shoes)          (Bottle)    0.025    0.337838  1.005470
# 13   (Shoes, Bottle)            (Bike)    0.025    0.301205  1.064328
# 16    (Bike, Gloves)          (Helmet)    0.026    0.346667  1.016618
# 18    (Bike, Gloves)           (Socks)    0.029    0.386667  1.154229
# 20    (Bike, Helmet)           (Socks)    0.033    0.366667  1.094527
# 21   (Helmet, Socks)            (Bike)    0.033    0.297297  1.050520
# 22            (Bike)   (Helmet, Socks)    0.033    0.116608  1.050520
# 24  (Gloves, Bottle)          (Shorts)    0.033    0.347368  1.142659
# 25  (Gloves, Shorts)          (Bottle)    0.033    0.354839  1.056068
# 26  (Bottle, Shorts)          (Gloves)    0.033    0.336735  1.055595
# 27          (Gloves)  (Bottle, Shorts)    0.033    0.103448  1.055595
# 29          (Shorts)  (Gloves, Bottle)    0.033    0.108553  1.142659
# 30   (Socks, Bottle)          (Shorts)    0.038    0.336283  1.106195
# 31   (Socks, Shorts)          (Bottle)    0.038    0.365385  1.087454
# 32  (Bottle, Shorts)           (Socks)    0.038    0.387755  1.157478
# 33           (Socks)  (Bottle, Shorts)    0.038    0.113433  1.157478
# 34          (Bottle)   (Socks, Shorts)    0.038    0.113095  1.087454
# 35          (Shorts)   (Socks, Bottle)    0.038    0.125000  1.106195
# 36  (Gloves, Shorts)           (Socks)    0.032    0.344086  1.027122
# 38   (Shoes, Jersey)          (Shorts)    0.025    0.304878  1.002888
# 39   (Shoes, Shorts)          (Jersey)    0.025    0.328947  1.115076
